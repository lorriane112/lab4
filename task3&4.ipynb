# %% [markdown]
# ### 学习目标
# #### 1. 学会阅读文档
# #### 2. 学会使用API
# #### 3. 尝试在MNIST上应用Scikit-Learn中的聚类和降维

# %% [markdown]
# ### 0x1. SVM、SVC （IRIS数据集）
# #### SVC文档：https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("ticks")
from sklearn import datasets, svm
from sklearn.inspection import DecisionBoundaryDisplay

# import some data to play with
iris = datasets.load_iris()
# Take the first two features. We could avoid this by using a two-dim dataset
X = iris.data[:, :2]
y = iris.target

C = 1.0  # SVM regularization parameter
clf = svm.SVC(kernel="linear", C=C)
model = clf.fit(X, y)


## 可视化代码
fig, ax = plt.subplots(1, 1)
title = 'SVC (Linear)'

disp = DecisionBoundaryDisplay.from_estimator(
    clf,
    X,
    response_method="predict",
    cmap=plt.cm.coolwarm,
    alpha=0.8,
    ax=ax,
    xlabel=iris.feature_names[0],
    ylabel=iris.feature_names[1],
)

X0, X1 = X[:, 0], X[:, 1]
ax.scatter(X0, X1, c=y, cmap=plt.cm.coolwarm, s=20, edgecolors="k")
ax.set_xticks(())
ax.set_yticks(())
ax.set_title(title)
plt.show()

# %% [markdown]
# ### 0x2. 聚类算法（K-Means、DBScan）
# #### K-Means文档：https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html#:~:text=The%20k-means%20problem%20is%20solved%20using%20either%20Lloyd%E2%80%99s%20or%20Elkan%E2%80%99s
# #### DBScan: https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html
# #### numpy入门：https://www.runoob.com/numpy/numpy-tutorial.html

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

X1, y1=datasets.make_circles(n_samples=5000, factor=.6,
                                      noise=.05)
X2, y2 = datasets.make_blobs(n_samples=1000, n_features=2, centers=[[1.2,1.2]], cluster_std=[[.1]],
               random_state=9)

X = np.concatenate((X1, X2))
plt.scatter(X[:, 0], X[:, 1], marker='o')
plt.show()

"""
任务1：调用K-Means
"""
def apply_kmeans(X):
    Y = np.random.randint(0, 3, size=(X.shape[0],))
    ### TODO：查阅文档，调用
    return Y


y_pred = apply_kmeans(X)

### 可视化聚类结果
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()


"""
任务2：调用DBScan
"""
def apply_dbscan(X):
    Y = np.random.randint(0, 5, size=(X.shape[0],))
    ### TODO：查阅文档，调用
    return Y


y_pred = apply_dbscan(X)
### 可视化聚类结果
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()

# %%
### 0x3. 降维算法（PCA、t-SNE）
#### PCA文档：https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html
#### DBScan: https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html#:~:text=t-SNE%20%5B1%5D%20is%20a%20tool%20to%20visualize%20high-dimensional%20data.%20It

# %%
import numpy as np

from sklearn.datasets import load_digits

data, labels = load_digits(return_X_y=True)
(n_samples, n_features), n_digits = data.shape, np.unique(labels).size

print(f"# digits: {n_digits}; # samples: {n_samples}; # features {n_features}")


"""
任务3：调用PCA
"""
def pca_2D_reduced(data):
    ### TODO：查阅文档，调用
    return data[:, :2] 

reduced_data = pca_2D_reduced(data) 

### 可视化降维结果
plt.plot(reduced_data[:, 0], reduced_data[:, 1], "g.", markersize=2, c='g')
plt.xticks(())
plt.yticks(())
plt.show()

"""
任务4：调用t-SNE
"""
def tsne_2D_reduced(data):
    ### TODO：查阅文档，调用
    return  data[:, :2] 


reduced_data = tsne_2D_reduced(data) 

### 可视化降维结果
plt.plot(reduced_data[:, 0], reduced_data[:, 1], "r.", markersize=2)
plt.xticks(())
plt.yticks(())
plt.show()
# Out:
# # digits: 10; # samples: 1797; # features 64
# /tmp/ipykernel_350/1492171951.py:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "g." (-> color='g'). The keyword argument will take precedence.
#   plt.plot(reduced_data[:, 0], reduced_data[:, 1], "g.", markersize=2, c='g')
